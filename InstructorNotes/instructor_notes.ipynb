# %%
from pathlib import Path

# %%
# Printing the current directory path
p = Path.cwd()
p
# Out:
# PosixPath('/Users/waleedmouhammed/Library/CloudStorage/OneDrive-Personal/Desktop/HealthReport/InstructorNotes')

# %%
base_path = Path('/Users/waleedmouhammed/Library/CloudStorage/OneDrive-Personal/Desktop/HealthReport')
for item in base_path.iterdir():
    if item.is_file():
        print(f"File name: {item.name}")
    else:
        print(f"Directory name: {item.name}")
# Out:
# File name: fetch.py
# File name: walking_dashboard.py
# File name: auth.py
# Directory name: InstructorNotes
# File name: state.json
# File name: config.py
# File name: HealthReport_Strava_Sync_Documentation.docx
# File name: requirements.txt
# File name: pyproject.toml
# Directory name: output
# File name: tokens.py
# Directory name: .venv-wm
# Directory name: __pycache__
# File name: export.py
# File name: README.md
# Directory name: logs
# Directory name: .venv-macbook
# File name: .gitignore
# File name: .env
# File name: transform.py
# Directory name: .venv
# Directory name: scripts
# File name: .env.example
# Directory name: .git
# Directory name: .vscode
# File name: main.py
# File name: tokens.json

# %%
from pathlib import Path
PROJECT_ROOT = Path(__file__).resolve().parents[1]
print(PROJECT_ROOT)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 from pathlib import Path
# ----> 2 PROJECT_ROOT = Path(__file__).resolve().parents[1]
#       3 print(PROJECT_ROOT)
#
# NameError: name '__file__' is not defined
